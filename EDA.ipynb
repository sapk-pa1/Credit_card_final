# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
# importing some fundamental libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import matplotlib.gridspec as gridspec


from sklearn.model_selection import train_test_split

# %% [markdown]
# # EDA

# %% [markdown]
# For a dataset the generally lets do the following check
# - checking for missing value
# - checking for duplicated value
# - checking the what are the values of the columns to see unusual entry

# %%
credit_card = pd.read_csv('dataset/creditcard.csv')
pd.set_option('display.max_columns', None)

# %%
credit_card.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
credit_card.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# not much of the inforamtion from v1 to v28 which are the columns due to the pca 
# also the time columns has unusual data 
# amount and class seeems to be the columns we can make sense of.

# %%
# lets convert the time(which is in seconds to the hour )
df['Time'] = df['Time'].apply(lambda x: x/3600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # lets convert the time(which is in seconds to the hour )
# ----> 2 df['Time'] = df['Time'].apply(lambda x: x/3600)
#
# NameError: name 'df' is not defined

# %%
# lets get the general statistics of the dataframe 
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# There an no null values

# %%
# getting total number of duplicated records
credit_card.duplicated().sum()
# Out:
# 1081

# %%
credit_card.drop_duplicates(keep ='first', inplace= True)

# %%
credit_card.duplicated().sum()
# Out:
# 0

# %%
# from the above we can clearly see that there is no non-null values 
# we can check the unique values in the data sets 
def get_unique_values(col): 
    print("*"*100)
    print(" "*100)
    print(f"Unique Values for Columns: {col.name} are : ")
    print(col.unique()) 
    print("*"*100)
    print(" "*100)

# %%
for col in credit_card.columns: 
    get_unique_values(credit_card[col])
# Out:
# ****************************************************************************************************
#
# Unique Values for Columns: Time are :
# [0.00000e+00 1.00000e+00 2.00000e+00 ... 1.72787e+05 1.72788e+05
#  1.72792e+05]
# ****************************************************************************************************
#
# ****************************************************************************************************
#
# Unique Values for Columns: V1 are :
# [-1.35980713  1.19185711 -1.35835406 ...  1.91956501 -0.24044005
#  -0.53341252]
# ****************************************************************************************************
#
# ****************************************************************************************************
#
# Unique Values for Columns: V2 are :
# [-0.07278117  0.26615071 -1.34016307 ... -0.30125385  0.53048251
#  -0.18973334]
# ****************************************************************************************************
#
# ...

# %%
# Getting some visualization about the dataset

# %%
# Let try to get an idea about the two transactions 
transactions = credit_card['Class'].value_counts() 
transactions
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
transactions.plot(kind = 'bar', color = ['g', 'r'], width = 0.5, figsize = (7,3))
plt.title("Number of fradulent and non-fradulent transaction")
plt.xlabel("Class")
plt.ylabel("No of Transaction");

# %%
plt.pie(x = credit_card['Class'].value_counts(), explode =[0,0.3], 
        labels = ['Valid Transaction(Class 0)', 'Fraud Transaction(Class 1)'], 
        colors = ['g', 'r'], shadow= True ,autopct='%2.2f%%')
plt.title("Fraudulent  and valid Transaction")
plt.legend(["Valid", "Fraud"]);

# %%
# From the above visualization we can clearly see that it is a class imbalance problem with positive class( what we are trying to predict fraud)
# with 0.17% of the transactions being only fraud transaction 
# so we have to find some method to fix this problem

# %%
len(credit_card['Class']==0)
# Out:
# 283726

# %%
# we have all these v1 -  v28 columns which are result of the pca transformation , of whose we can make sense of 
# for the privacy reason there features are anonymous 
# lets try to make some sense out it seing their distribution

# %%
features = credit_card.columns
v_features = features[1:-2]
v_features
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28'],
#       dtype='object')

# %%
plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(v_features):
    ax = plt.subplot(gs[i])
    sns.distplot(credit_card[cn][credit_card.Class == 1], bins=50)
    sns.distplot(credit_card[cn][credit_card.Class == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
plt.show()

# %%
# from the above graph we can see that the columns follow a distibtuion  with some of these columns centred at 0 , while 
# fraud and non fraud follow same distribution for some cases 
# v15 has similar distribution for the fraud and non fraud case so this column should be removed 
# either we are removing or not will be decided later with correlation heatmap

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

amount_val = credit_card['Amount'].values
time_val = credit_card['Time'].values

sns.histplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.histplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])
# Out:
# (0.0, 172792.0)

# %%
# Due to the outliers we cannot see the transaction amount distribution properly so lets try to remove the outliers to make 
# another plot so that we can get an idea of the distribution

# %%
def remove_outliers(data, threshold=3):
    z_scores = np.abs((data - np.mean(data)) / np.std(data))
    filtered_data = data[z_scores < threshold]
    return filtered_data

# %%
non_outliers = remove_outliers(credit_card["Amount"])

# %%
fig, ax = plt.subplots(1, 1, figsize=(18,4))

amount_val = non_outliers
sns.histplot(amount_val, ax=ax, color='r', bins =40)
ax.set_title('Distribution of Transaction Amount', fontsize=14)
ax.set_xlim([min(amount_val), max(amount_val)])
# Out:
# (0.0, 839.5)

# %%
# from the above plot we clearly see the maximum numbers of transactions are in the lower range , lets see if fraud are 
# present in the lesser amount or higher amount

# %%
# Lets make a bivariate analysis of the field Amount and Time 
valid = credit_card[credit_card.Class == 0]
fraud = credit_card[credit_card.Class==1]
#A plot between the Amount and the time values 
fig = plt.figure(figsize=(10,6))
plt.scatter(valid.Amount, valid.Time.values/(60*60), label = "Non-Fraudulent Transactions",alpha = 0.5, color = 'green')
plt.scatter(fraud.Amount, fraud.Time.values/(60*60), label = "Fraudulent Transactions",alpha = 1,  color = 'red')
plt.legend()
plt.xlabel("Amount")
plt.ylabel("Time in Hrs ")
plt.title("Plot of the Amount and Time for the Fradulent and Non-Fradulent Transactions")
plt.show()

# %%
# from the above observation we can see that most of the fraduelent trasaction aren't in the high range and happening between 
# amount 0 to 2500 in this data set. Maybe the fraudulent was being wary of making a big transaction as bank might flag them 
# suspicious

# %%
#Lets make a box plot to better visualize it 
plt.figure(figsize = (15, 6))
plt.subplot(121)
a = sns.boxplot(x = 'Class', y = 'Amount',hue='Class', data = credit_card, showfliers=False) 
# plt.setp(a.get_xticklabels(), rotation=45)

# %%
# The data is very skewed, 50 % of the data lies below the amount 15 , lets get some numbers about the amount for both 
# fraud and valid transaction

# %%
valid.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# correlation analysis

# %%
corr = credit_card.corr()

# %%
# Create a clustered heatmap
sns.clustermap(corr, cmap='coolwarm', linewidths=0.5, annot=False)

# # Rotate x-axis labels for better readability
# plt.xticks(rotation=90)

# # Display the plot
# plt.show()

# %%
# from the above figure we can say that the are no significant correlation  , so we will have to work with all the 
# fields from the dataset removing v15 which has similar distribution for the valid and fraud transaction
